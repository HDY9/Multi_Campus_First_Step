# %%
import numpy as np 
import pandas as pd 

# %matplotlib inline

# %%
# 2016-05-25 ~ 2016-02-29 까지 코스피 지수 

pd.read_csv('kospi3.csv')
# Out:
#           date  close
# 0   2016-05-25   1961
# 1   2016-05-24   1938
# 2   2016-05-23   1955
# 3   2016-05-20   1948
# 4   2016-05-19   1947
# 5   2016-05-18   1957
# 6   2016-05-17   1968
# 7   2016-05-16   1968
# 8   2016-05-13   1967
# 9   2016-05-12   1977
# 10  2016-05-11   1980
# 11  2016-05-10   1983
# 12  2016-05-09   1968
# 13  2016-05-04   1977
# 14  2016-05-03   1986
# 15  2016-05-02   1978
# 16  2016-04-29   1994
# 17  2016-04-28   2001
# 18  2016-04-27   2015
# 19  2016-04-26   2020
# 20  2016-04-25   2015
# 21  2016-04-22   2015
# 22  2016-04-21   2022
# 23  2016-04-20   2006
# 24  2016-04-19   2011
# 25  2016-04-18   2009
# 26  2016-04-15   2015
# 27  2016-04-14   2016
# 28  2016-04-12   1981
# 29  2016-04-11   1970
# 30  2016-04-08   1972
# 31  2016-04-07   1974
# 32  2016-04-06   1971
# 33  2016-04-05   1963
# 34  2016-04-04   1979
# 35  2016-04-01   1974
# 36  2016-03-31   1996
# 37  2016-03-30   2002
# 38  2016-03-29   1995
# 39  2016-03-28   1983
# ...

# %%
pd.read_csv('kospi3.csv', header=0, index_col=0)
# Out:
#             close
# date
# 2016-05-25   1961
# 2016-05-24   1938
# 2016-05-23   1955
# 2016-05-20   1948
# 2016-05-19   1947
# 2016-05-18   1957
# 2016-05-17   1968
# 2016-05-16   1968
# 2016-05-13   1967
# 2016-05-12   1977
# 2016-05-11   1980
# 2016-05-10   1983
# 2016-05-09   1968
# 2016-05-04   1977
# 2016-05-03   1986
# 2016-05-02   1978
# 2016-04-29   1994
# 2016-04-28   2001
# 2016-04-27   2015
# 2016-04-26   2020
# 2016-04-25   2015
# 2016-04-22   2015
# 2016-04-21   2022
# 2016-04-20   2006
# 2016-04-19   2011
# 2016-04-18   2009
# 2016-04-15   2015
# 2016-04-14   2016
# 2016-04-12   1981
# 2016-04-11   1970
# 2016-04-08   1972
# 2016-04-07   1974
# 2016-04-06   1971
# 2016-04-05   1963
# 2016-04-04   1979
# 2016-04-01   1974
# 2016-03-31   1996
# 2016-03-30   2002
# 2016-03-29   1995
# 2016-03-28   1983
# 2016-03-25   1984
# 2016-03-24   1986
# 2016-03-23   1995
# 2016-03-22   1997
# 2016-03-21   1990
# 2016-03-18   1992
# 2016-03-17   1988
# 2016-03-16   1975
# ...

# %%
series = pd.read_csv('kospi3.csv', header=0, index_col=0)
series.plot()

# %%
import matplotlib.pyplot as plt 
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# acf, pacf 곡선 그리기 
plot_acf(series)
plot_pacf(series)
plt.show()

# 결과 해석 
# ACF의 첫 번째 구간 : 영향력을 미치는 구간
# ACF 의 실내 공간 : 영향력이 없음 

# PACF 첫 번째 영향구간

# %%
series.head()
# Out:
#             close
# date
# 2016-05-25   1961
# 2016-05-24   1938
# 2016-05-23   1955
# 2016-05-20   1948
# 2016-05-19   1947

# %%
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# ARIMA(1,2,1) 모델 생성하고 훈련하기 

model = ARIMA(series, order=(1,2,1)) # (p,d,q) AR + I + MA : 차분을 두 번: d를 2로 설정  
model_fit=model.fit(trend='c', full_output=True, disp=1)
# trend='c' means including constant, 'nc' no constant(추세)
print(model_fit.summary())

# 결과 해석 
# P>|z| (p-value): constant  0.074, ar 0.791  값이 좋지 않음, ma 0.00
# ar 삭제 >> 0 (0,2,1)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:               D2.close   No. Observations:                   57
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -217.690
# Method:                       css-mle   S.D. of innovations             10.632
# Date:                Tue, 07 Jun 2022   AIC                            443.379
# Time:                        02:19:15   BIC                            451.551
# Sample:                             2   HQIC                           446.555
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1465      0.080     -1.823      0.074      -0.304       0.011
# ar.L1.D2.close    -0.0396      0.149     -0.266      0.791      -0.332       0.252
# ma.L1.D2.close    -1.0000      0.050    -19.896      0.000      -1.099      -0.901
# ...

# %%
from statsmodels.tsa.arima_model import ARIMA

# ARIMA(1,2,1) 모델 생성하고 훈련하기 

model = ARIMA(series, order=(0,2,1)) # (p,d,q) AR + I + MA : 차분을 두 번: d를 2로 설정  
model_fit=model.fit(trend='nc', full_output=True, disp=1)
# trend='c' means including constant, 'nc' no constant(추세)
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:               D2.close   No. Observations:                   57
# Model:                 ARIMA(0, 2, 1)   Log Likelihood                -218.944
# Method:                       css-mle   S.D. of innovations             11.055
# Date:                Tue, 07 Jun 2022   AIC                            441.887
# Time:                        02:22:27   BIC                            445.974
# Sample:                             2   HQIC                           443.475
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ma.L1.D2.close    -0.9430      0.059    -15.987      0.000      -1.059      -0.827
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# ...

# %%
model_fit.plot_predict()
# close(종가) : 실제 데이터, forecast 와 거의 유사하게 나타남

# %%
model_fit.forecast(steps=1) # 1단계 시점(t+1) 예측

# array([1913.77022316]) : 예측된 kospi
# array([11.0549821]) : 분산 
# array([[1892.10285639, 1935.43758993]])) 신뢰구간
# Out:
# (array([1913.77022316]),
#  array([11.0549821]),
#  array([[1892.10285639, 1935.43758993]]))

# %%
model_fit.forecast(steps=10)
# Out:
# (array([1913.77022316, 1910.54044632, 1907.31066948, 1904.08089264,
#         1900.8511158 , 1897.62133897, 1894.39156213, 1891.16178529,
#         1887.93200845, 1884.70223161]),
#  array([11.0549821 , 16.08556909, 20.25813108, 24.0404829 , 27.60792507,
#         31.04743409, 34.40893624, 37.7238105 , 41.01303797, 44.29128889]),
#  array([[1892.10285639, 1935.43758993],
#         [1879.01331023, 1942.06758241],
#         [1867.60546218, 1947.01587679],
#         [1856.96241199, 1951.19937329],
#         [1846.74057699, 1954.96165462],
#         [1836.76948634, 1958.4731916 ],
#         [1826.95128635, 1961.8318379 ],
#         [1817.22447535, 1965.09909523],
#         [1807.54793113, 1968.31608577],
#         [1797.89290055, 1971.51156267]]))
