# %% [markdown]
# * 데이터 수집
#   http://data.seoul.go.kr/dataList/OA-12252/S/1/datasetView.do

# %%
import pandas as pd

# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리 가져온다.
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# 폰트 지정하기
plt.rcParams['font.family'] = 'gulim'

# %% [markdown]
# # 데이터 확인 및 전처리
#  * 월별, 시간대별, 역별 지하철 승하차정보 데이터이다.

# %%
pd.read_csv('서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv', encoding='cp949')
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 0      202108  1호선  동대문           415            11         10380
# 1      202108  1호선  동묘앞            84             3          2861
# 2      202108  1호선  서울역           483            11          7963
# 3      202108  1호선   시청             6             0          1597
# 4      202108  1호선  신설동           247             6          6828
# ...       ...  ...  ...           ...           ...           ...
# 46547  201501  중앙선  운길산             0             0           177
# 46548  201501  중앙선   원덕             1             0           292
# 46549  201501  중앙선   중랑            14             1          4929
# 46550  201501  중앙선   팔당             0             0           161
# 46551  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 0              1815          7880          5352         12037  ...
# ...

# %%
df = pd.read_csv('서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv', encoding='cp949')

# %%
df.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
# 2  202108  1호선  서울역           483            11          7963          5533
# 3  202108  1호선   시청             6             0          1597          4399
# 4  202108  1호선  신설동           247             6          6828          2721
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 하차인원  00시-01시 승차인원  \
# 0          7880          5352         12037  ...          5983             7
# 1          3286          4614          5128  ...          1759             4
# 2         10871         31479         31643  ...          4968            21
# 3          2727         17957          5971  ...           822             3
# 4          7333          9771         14821  ...          3747            15
#
# ...

# %%
df.tail()
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 46547  201501  중앙선  운길산             0             0           177
# 46548  201501  중앙선   원덕             1             0           292
# 46549  201501  중앙선   중랑            14             1          4929
# 46550  201501  중앙선   팔당             0             0           161
# 46551  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 46547            56           642           403          1292  ...
# 46548             4           415            46           537  ...
# 46549           424          8539          2084         22160  ...
# 46550            50           368           149          1227  ...
# 46551          3067         23317         10430         65043  ...
#
#        23시-24시 하차인원  00시-01시 승차인원  00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  \
# 46547           633             3           222             0             0
# ...

# %% [markdown]
# ## 데이터 크기

# %%
df.shape
# Out:
# (46552, 52)

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# 사용월             0
# 호선명             0
# 지하철역            0
# 04시-05시 승차인원    0
# 04시-05시 하차인원    0
# 05시-06시 승차인원    0
# 05시-06시 하차인원    0
# 06시-07시 승차인원    0
# 06시-07시 하차인원    0
# 07시-08시 승차인원    0
# 07시-08시 하차인원    0
# 08시-09시 승차인원    0
# 08시-09시 하차인원    0
# 09시-10시 승차인원    0
# 09시-10시 하차인원    0
# 10시-11시 승차인원    0
# 10시-11시 하차인원    0
# 11시-12시 승차인원    0
# 11시-12시 하차인원    0
# 12시-13시 승차인원    0
# 12시-13시 하차인원    0
# 13시-14시 승차인원    0
# 13시-14시 하차인원    0
# 14시-15시 승차인원    0
# 14시-15시 하차인원    0
# 15시-16시 승차인원    0
# 15시-16시 하차인원    0
# 16시-17시 승차인원    0
# 16시-17시 하차인원    0
# 17시-18시 승차인원    0
# 17시-18시 하차인원    0
# 18시-19시 승차인원    0
# 18시-19시 하차인원    0
# 19시-20시 승차인원    0
# 19시-20시 하차인원    0
# 20시-21시 승차인원    0
# 20시-21시 하차인원    0
# 21시-22시 승차인원    0
# 21시-22시 하차인원    0
# 22시-23시 승차인원    0
# 22시-23시 하차인원    0
# 23시-24시 승차인원    0
# 23시-24시 하차인원    0
# 00시-01시 승차인원    0
# 00시-01시 하차인원    0
# 01시-02시 승차인원    0
# 01시-02시 하차인원    0
# 02시-03시 승차인원    0
# 02시-03시 하차인원    0
# 03시-04시 승차인원    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46552 entries, 0 to 46551
# Data columns (total 52 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   사용월           46552 non-null  int64
#  1   호선명           46552 non-null  object
#  2   지하철역          46552 non-null  object
#  3   04시-05시 승차인원  46552 non-null  int64
#  4   04시-05시 하차인원  46552 non-null  int64
#  5   05시-06시 승차인원  46552 non-null  int64
#  6   05시-06시 하차인원  46552 non-null  int64
#  7   06시-07시 승차인원  46552 non-null  int64
#  8   06시-07시 하차인원  46552 non-null  int64
#  9   07시-08시 승차인원  46552 non-null  int64
#  10  07시-08시 하차인원  46552 non-null  int64
#  11  08시-09시 승차인원  46552 non-null  int64
#  12  08시-09시 하차인원  46552 non-null  int64
#  13  09시-10시 승차인원  46552 non-null  int64
#  14  09시-10시 하차인원  46552 non-null  int64
#  15  10시-11시 승차인원  46552 non-null  int64
#  16  10시-11시 하차인원  46552 non-null  int64
#  17  11시-12시 승차인원  46552 non-null  int64
# ...

# %% [markdown]
# ## 컬럼별 데이터 확인

# %%
# 사용월
df['사용월'].unique()
# Out:
# array([202108, 202107, 202106, 202105, 202104, 202103, 202102, 202101,
#        202012, 202011, 202010, 202009, 202008, 202007, 202006, 202005,
#        202004, 202003, 202002, 202001, 201912, 201911, 201910, 201909,
#        201908, 201907, 201906, 201905, 201904, 201903, 201902, 201901,
#        201812, 201811, 201810, 201809, 201808, 201807, 201806, 201805,
#        201804, 201803, 201802, 201801, 201712, 201711, 201710, 201709,
#        201708, 201707, 201706, 201705, 201704, 201703, 201702, 201701,
#        201612, 201611, 201610, 201609, 201608, 201607, 201606, 201605,
#        201604, 201603, 201602, 201601, 201512, 201511, 201510, 201509,
#        201508, 201507, 201506, 201505, 201504, 201503, 201502, 201501],
#       dtype=int64)

# %%
# 호선명
df['호선명'].unique()
# Out:
# array(['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '8호선', '9호선',
#        '9호선2~3단계', '경강선', '경부선', '경원선', '경의선', '경인선', '경춘선', '공항철도 1호선',
#        '과천선', '분당선', '수인선', '안산선', '우이신설선', '일산선', '장항선', '중앙선', '9호선2단계'],
#       dtype=object)

# %% [markdown]
# ## 데이터 타입 확인 및 변경

# %%
df.dtypes
# Out:
# 사용월              int64
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %%
# 사용월을 문자형으로 변환 
df['사용월'] = df['사용월'].astype('str') # dtype: object

# %%
df.dtypes
# Out:
# 사용월             object
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %% [markdown]
# ## 불필요한 컬럼 삭제

# %%
df.drop(columns=['작업일자'], inplace=True)

# %%
df.dtypes
# Out:
# 사용월             object
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %% [markdown]
# ## 승차/하차 테이블 분리

# %% [markdown]
# ### 승차 테이블 만들기

# %%
df.head(3)
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
# 2  202108  1호선  서울역           483            11          7963          5533
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 승차인원  23시-24시 하차인원  \
# 0          7880          5352         12037  ...          1633          5983
# 1          3286          4614          5128  ...           577          1759
# 2         10871         31479         31643  ...          7756          4968
#
#    00시-01시 승차인원  00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  02시-03시 승차인원  \
# 0             7          1043             2             2             0
# 1             4           827             0             0             0
# 2            21           444             1             1             0
#
#    02시-03시 하차인원  03시-04시 승차인원  03시-04시 하차인원
# ...

# %%
df.iloc[:,:3]
# Out:
#           사용월  호선명 지하철역
# 0      202108  1호선  동대문
# 1      202108  1호선  동묘앞
# 2      202108  1호선  서울역
# 3      202108  1호선   시청
# 4      202108  1호선  신설동
# ...       ...  ...  ...
# 46547  201501  중앙선  운길산
# 46548  201501  중앙선   원덕
# 46549  201501  중앙선   중랑
# 46550  201501  중앙선   팔당
# 46551  201501  중앙선   회기
#
# [46552 rows x 3 columns]

# %%
# 공통 컬럼
df_common = df.iloc[:,:3]

# %%
# 승차 컬럼만 가져오기 (see U soon)
df.iloc[:,3::2]
# Out:
#        04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 0               415         10380          7880         12037         16637
# 1                84          2861          3286          5128          8066
# 2               483          7963         10871         31643         49003
# 3                 6          1597          2727          5971          6884
# 4               247          6828          7333         14821         20523
# ...             ...           ...           ...           ...           ...
# 46547             0           177           642          1292          1479
# 46548             1           292           415           537           823
# 46549            14          4929          8539         22160         25792
# 46550             0           161           368          1227           910
# 46551           436         10929         23317         65043         85473
#
# ...

# %%
df_take = df.iloc[:,3::2]

# %%
df_take.head()
# Out:
#    04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 0           415         10380          7880         12037         16637
# 1            84          2861          3286          5128          8066
# 2           483          7963         10871         31643         49003
# 3             6          1597          2727          5971          6884
# 4           247          6828          7333         14821         20523
#
#    09시-10시 승차인원  10시-11시 승차인원  11시-12시 승차인원  12시-13시 승차인원  13시-14시 승차인원  ...  \
# 0         15671         13922         15675         18244         19566  ...
# 1          7541          9130         13369         18112         21526  ...
# 2         36383         35273         41477         48720         50740  ...
# 3          7541          8328         12240         13561         15934  ...
# 4         14881         13551         15578         16289         17701  ...
#
# ...

# %%
df.columns
# Out:
# Index(['사용월', '호선명', '지하철역', '04시-05시 승차인원', '04시-05시 하차인원', '05시-06시 승차인원',
#        '05시-06시 하차인원', '06시-07시 승차인원', '06시-07시 하차인원', '07시-08시 승차인원',
#        '07시-08시 하차인원', '08시-09시 승차인원', '08시-09시 하차인원', '09시-10시 승차인원',
#        '09시-10시 하차인원', '10시-11시 승차인원', '10시-11시 하차인원', '11시-12시 승차인원',
#        '11시-12시 하차인원', '12시-13시 승차인원', '12시-13시 하차인원', '13시-14시 승차인원',
#        '13시-14시 하차인원', '14시-15시 승차인원', '14시-15시 하차인원', '15시-16시 승차인원',
#        '15시-16시 하차인원', '16시-17시 승차인원', '16시-17시 하차인원', '17시-18시 승차인원',
#        '17시-18시 하차인원', '18시-19시 승차인원', '18시-19시 하차인원', '19시-20시 승차인원',
#        '19시-20시 하차인원', '20시-21시 승차인원', '20시-21시 하차인원', '21시-22시 승차인원',
#        '21시-22시 하차인원', '22시-23시 승차인원', '22시-23시 하차인원', '23시-24시 승차인원',
#        '23시-24시 하차인원', '00시-01시 승차인원', '00시-01시 하차인원', '01시-02시 승차인원',
#        '01시-02시 하차인원', '02시-03시 승차인원', '02시-03시 하차인원', '03시-04시 승차인원',
#        '03시-04시 하차인원'],
#       dtype='object')

# %%
df_take.columns
# Out:
# Index(['04시-05시 승차인원', '05시-06시 승차인원', '06시-07시 승차인원', '07시-08시 승차인원',
#        '08시-09시 승차인원', '09시-10시 승차인원', '10시-11시 승차인원', '11시-12시 승차인원',
#        '12시-13시 승차인원', '13시-14시 승차인원', '14시-15시 승차인원', '15시-16시 승차인원',
#        '16시-17시 승차인원', '17시-18시 승차인원', '18시-19시 승차인원', '19시-20시 승차인원',
#        '20시-21시 승차인원', '21시-22시 승차인원', '22시-23시 승차인원', '23시-24시 승차인원',
#        '00시-01시 승차인원', '01시-02시 승차인원', '02시-03시 승차인원', '03시-04시 승차인원'],
#       dtype='object')

# %%
df_take.columns.str.split(' ').str[0]
# Out:
# Index(['04시-05시', '05시-06시', '06시-07시', '07시-08시', '08시-09시', '09시-10시',
#        '10시-11시', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시',
#        '16시-17시', '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시',
#        '22시-23시', '23시-24시', '00시-01시', '01시-02시', '02시-03시', '03시-04시'],
#       dtype='object')

# %%
df_take.columns.str.split(' ').str[1]
# Out:
# Index(['승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원',
#        '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원',
#        '승차인원', '승차인원', '승차인원', '승차인원', '승차인원', '승차인원'],
#       dtype='object')

# %%
df_take.columns = df_take.columns.str.split(' ').str[0]

# %%
# 공통컬럼과 승차컬럼 연결하기
pd.concat([df_common, df_take], axis=1)
# Out:
#           사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1      202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 2      202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 3      202108  1호선   시청        6     1597     2727     5971     6884     7541
# 4      202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ...       ...  ...  ...      ...      ...      ...      ...      ...      ...
# 46547  201501  중앙선  운길산        0      177      642     1292     1479     1438
# 46548  201501  중앙선   원덕        1      292      415      537      823      980
# 46549  201501  중앙선   중랑       14     4929     8539    22160    25792    14328
# 46550  201501  중앙선   팔당        0      161      368     1227      910      897
# 46551  201501  중앙선   회기      436    10929    23317    65043    85473    54247
#
# ...

# %%
# 공통컬럼과 승차컬럼 연결하기
df_in = pd.concat([df_common, df_take], axis=1)

# %% [markdown]
# ## 하차 테이블 만들기

# %%
df.head(3)
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
# 2  202108  1호선  서울역           483            11          7963          5533
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 승차인원  23시-24시 하차인원  \
# 0          7880          5352         12037  ...          1633          5983
# 1          3286          4614          5128  ...           577          1759
# 2         10871         31479         31643  ...          7756          4968
#
#    00시-01시 승차인원  00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  02시-03시 승차인원  \
# 0             7          1043             2             2             0
# 1             4           827             0             0             0
# 2            21           444             1             1             0
#
#    02시-03시 하차인원  03시-04시 승차인원  03시-04시 하차인원
# ...

# %%
# 하차 컬럼만 가져오기
df_take_off = df.iloc[:, 4::2]
df_take_off.columns.str.split(' ').str[0]
# Out:
# Index(['04시-05시', '05시-06시', '06시-07시', '07시-08시', '08시-09시', '09시-10시',
#        '10시-11시', '11시-12시', '12시-13시', '13시-14시', '14시-15시', '15시-16시',
#        '16시-17시', '17시-18시', '18시-19시', '19시-20시', '20시-21시', '21시-22시',
#        '22시-23시', '23시-24시', '00시-01시', '01시-02시', '02시-03시', '03시-04시'],
#       dtype='object')

# %%
df_take_off.columns = df_take_off.columns.str.split(' ').str[0]

# %%
# 공통컬럼과 하차컬럼 연결하기
pd.concat([df_common, df_take_off], axis=1)
# Out:
#           사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0      202108  1호선  동대문       11     1815     5352     9885    19783    19192
# 1      202108  1호선  동묘앞        3      918     4614     8004    18779    15213
# 2      202108  1호선  서울역       11     5533    31479    73669   149249    94786
# 3      202108  1호선   시청        0     4399    17957    53669   141150    60972
# 4      202108  1호선  신설동        6     2721     9771    21765    52910    28274
# ...       ...  ...  ...      ...      ...      ...      ...      ...      ...
# 46547  201501  중앙선  운길산        0       56      403      675     1390     3270
# 46548  201501  중앙선   원덕        0        4       46      248      344      273
# 46549  201501  중앙선   중랑        1      424     2084     3027     6573     6133
# 46550  201501  중앙선   팔당        0       50      149      523     1151     2931
# 46551  201501  중앙선   회기        3     3067    10430    24473    59383    41911
#
# ...

# %%
df_out = pd.concat([df_common, df_take_off], axis=1)

# %%
df_out.head(1)
# Out:
#       사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  202108  1호선  동대문       11     1815     5352     9885    19783    19192
#
#    10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 0    17298  ...    16304    15398    10356     8870     7191     5983
#
#    00시-01시  01시-02시  02시-03시  03시-04시
# 0     1043        2        2        0
#
# [1 rows x 27 columns]

# %% [markdown]
# # 출퇴근시간 역별 승하차인원 분석

# %% [markdown]
# * 최근 월을 기준으로 한 승하차 데이터프레임 생성

# %%
df['사용월'].unique()
# Out:
# array(['202108', '202107', '202106', '202105', '202104', '202103',
#        '202102', '202101', '202012', '202011', '202010', '202009',
#        '202008', '202007', '202006', '202005', '202004', '202003',
#        '202002', '202001', '201912', '201911', '201910', '201909',
#        '201908', '201907', '201906', '201905', '201904', '201903',
#        '201902', '201901', '201812', '201811', '201810', '201809',
#        '201808', '201807', '201806', '201805', '201804', '201803',
#        '201802', '201801', '201712', '201711', '201710', '201709',
#        '201708', '201707', '201706', '201705', '201704', '201703',
#        '201702', '201701', '201612', '201611', '201610', '201609',
#        '201608', '201607', '201606', '201605', '201604', '201603',
#        '201602', '201601', '201512', '201511', '201510', '201509',
#        '201508', '201507', '201506', '201505', '201504', '201503',
#        '201502', '201501'], dtype=object)

# %%
df_in[df_in['사용월'] == '202108']
# Out:
#         사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0    202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1    202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 2    202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 3    202108  1호선   시청        6     1597     2727     5971     6884     7541
# 4    202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ..      ...  ...  ...      ...      ...      ...      ...      ...      ...
# 602  202108  중앙선   원덕       72      277      689      643      883      755
# 603  202108  중앙선   중랑      200     5961     8782    19739    18610    13213
# 604  202108  중앙선   지평        0        1        2      347      218       18
# 605  202108  중앙선   팔당        1      212      788     1261     1267     1123
# 606  202108  중앙선   회기      719    11133    18619    47471    59922    39563
#
# ...

# %%
df_in_202108 = df_in[df_in['사용월'] == '202108']

# %%
df_out[df_out['사용월'] == '202108']
# Out:
#         사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0    202108  1호선  동대문       11     1815     5352     9885    19783    19192
# 1    202108  1호선  동묘앞        3      918     4614     8004    18779    15213
# 2    202108  1호선  서울역       11     5533    31479    73669   149249    94786
# 3    202108  1호선   시청        0     4399    17957    53669   141150    60972
# 4    202108  1호선  신설동        6     2721     9771    21765    52910    28274
# ..      ...  ...  ...      ...      ...      ...      ...      ...      ...
# 602  202108  중앙선   원덕        0        1      261      477      613      522
# 603  202108  중앙선   중랑        4      572     2261     2544     5744     4790
# 604  202108  중앙선   지평        0        0        0      298       58        3
# 605  202108  중앙선   팔당        0      117      783     1603     2790     3084
# 606  202108  중앙선   회기       12     3419    10520    24212    40739    26807
#
# ...

# %%
df_out_202108 = df_out[df_out['사용월'] == '202108']

# %% [markdown]
# * 출근시간에 가장 많은 사람이 승차하는 역은 어디일까? (08시-09시)

# %%
df_in_202108.nlargest(10, '08시-09시')
# Out:
#         사용월  호선명         지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  \
# 37   202108  2호선           신림      234    37299    68898   173383   267128
# 14   202108  2호선      구로디지털단지      380    36602    46959   113543   153411
# 28   202108  2호선  서울대입구(관악구청)     4228    26357    38068   104693   150090
# 83   202108  3호선          연신내      258    25123    45977   110377   132615
# 133  202108  5호선          까치산      101    22441    37596   104308   130443
# 52   202108  2호선     잠실(송파구청)      115     9601    39179    94913   128005
# 175  202108  5호선           화곡       91    20535    35222    95552   121310
# 112  202108  4호선           쌍문      148    20967    46183   103811   112812
# 36   202108  2호선          신도림     3355    32032    43362   109140   111452
# 35   202108  2호선          신대방      174    23641    33197    75798   110766
#
#      09시-10시  10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# ...

# %%
df_in_202108.nlargest(10, '08시-09시')[['지하철역', '08시-09시']]
# Out:
#             지하철역  08시-09시
# 37            신림   267128
# 14       구로디지털단지   153411
# 28   서울대입구(관악구청)   150090
# 83           연신내   132615
# 133          까치산   130443
# 52      잠실(송파구청)   128005
# 175           화곡   121310
# 112           쌍문   112812
# 36           신도림   111452
# 35           신대방   110766

# %% [markdown]
# * 출근시간에 가장 많은 사람이 하차하는 역은 어디일까?(09시-10시)

# %%
df_out_202108.nlargest(10, '09시-10시')
# Out:
#         사용월  호선명        지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  \
# 10   202108  2호선          강남        4    10411    45059   129595   269877
# 43   202108  2호선          역삼        3     7114    34348   113759   273619
# 215  202108  7호선     가산디지털단지        4     5696    23409   105948   336272
# 30   202108  2호선          선릉        1     5979    36776    95870   230691
# 26   202108  2호선    삼성(무역센터)        5     4588    36821   106997   252453
# 80   202108  3호선         압구정        0     1906    20898    39481   116615
# 31   202108  2호선          성수        1     3388    26156    67921   228228
# 78   202108  3호선          신사        4     1441    18639    37899    96332
# 13   202108  2호선  교대(법원.검찰청)        0     6589    22451    50258   134527
# 14   202108  2호선     구로디지털단지        8     5316    19541    75822   217289
#
#      09시-10시  10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 10    274355   129744  ...   125891    68747    34635    27783    21970
# ...

# %%
df_out_202108.nlargest(10, '09시-10시')[['지하철역','09시-10시']]
# Out:
#            지하철역  09시-10시
# 10           강남   274355
# 43           역삼   226437
# 215     가산디지털단지   188412
# 30           선릉   178766
# 26     삼성(무역센터)   172539
# 80          압구정   139283
# 31           성수   124935
# 78           신사   122905
# 13   교대(법원.검찰청)   121163
# 14      구로디지털단지   121092

# %% [markdown]
# * 퇴근시간에 가장 많은 사람이 승차하는 역은 어디일까?(18시-19시)

# %%
df_in_202108.nlargest(10,'18시-19시')[['지하철역', '18시-19시']]
# Out:
#             지하철역  18시-19시
# 10            강남   302398
# 215      가산디지털단지   283125
# 30            선릉   245318
# 43            역삼   239209
# 26      삼성(무역센터)   230299
# 50         을지로입구   207093
# 31            성수   202624
# 14       구로디지털단지   192537
# 82      양재(서초구청)   174296
# 128  광화문(세종문화회관)   173772

# %%
df_in_202108.nlargest(10,'19시-20시')[['지하철역', '19시-20시']]
# Out:
#          지하철역  19시-20시
# 10         강남   178242
# 43         역삼   120972
# 215   가산디지털단지   117957
# 26   삼성(무역센터)   117148
# 30         선릉   116743
# 59       홍대입구   106107
# 52   잠실(송파구청)   104738
# 14    구로디지털단지    90513
# 31         성수    86392
# 80        압구정    83882

# %%
df_in_202108.nlargest(10,'20시-21시')[['지하철역', '20시-21시']]
# Out:
#          지하철역  20시-21시
# 10         강남   138452
# 52   잠실(송파구청)   109713
# 59       홍대입구   104619
# 63      고속터미널    97789
# 26   삼성(무역센터)    91086
# 360       영등포    74616
# 50      을지로입구    72237
# 363        용산    69802
# 30         선릉    69492
# 43         역삼    66771

# %% [markdown]
# * 퇴근시간에 가장 많은 사람이 하차하는 역은 어디일까?(19시-20시)

# %%
df_out_202108.nlargest(10,'19시-20시')[['지하철역', '19시-20시']]
# Out:
#             지하철역  19시-20시
# 37            신림   182832
# 28   서울대입구(관악구청)   121426
# 52      잠실(송파구청)   116568
# 14       구로디지털단지   107520
# 83           연신내   103283
# 36           신도림    97759
# 109     수유(강북구청)    93666
# 133          까치산    87948
# 112           쌍문    86631
# 438           부천    85018

# %% [markdown]
# # 강남역의 최근 시간대별 승하차정보 분석

# %% [markdown]
# ## 강남역의 최근 승차정보 분석

# %%
df_in_202108.head(3)
# Out:
#       사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1  202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 2  202108  1호선  서울역      483     7963    10871    31643    49003    36383
#
#    10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 0    13922  ...    20332    13464    10336     9669     6514     1633
# 1     9130  ...    19551     8704     5031     4235     2678      577
# 2    35273  ...   152659    72119    47289    51106    27974     7756
#
#    00시-01시  01시-02시  02시-03시  03시-04시
# 0        7        2        0        0
# 1        4        0        0        0
# 2       21        1        0        0
#
# [3 rows x 27 columns]

# %%
# 강남역의 최근 승차 데이터 불러오기 
condition = df_in_202108['지하철역'] == '강남'
df_in_202108[condition].iloc[:, 3:]
# Out:
#     04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 10       64     4993    14177    31783    50239    40611    44108    59573
#
#     12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 10    75942    88926  ...   302398   178242   138452   157847   105997
#
#     23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 10    12509        5        2        0        0
#
# [1 rows x 24 columns]

# %%
df_gangnam_in = df_in_202108[condition].iloc[:, 3:]
# df_gangnam_in

# %%
# melt
df_gangnam_in.melt()
# Out:
#    variable   value
# 0   04시-05시      64
# 1   05시-06시    4993
# 2   06시-07시   14177
# 3   07시-08시   31783
# 4   08시-09시   50239
# 5   09시-10시   40611
# 6   10시-11시   44108
# 7   11시-12시   59573
# 8   12시-13시   75942
# 9   13시-14시   88926
# 10  14시-15시   97964
# 11  15시-16시  120268
# 12  16시-17시  135621
# 13  17시-18시  214990
# 14  18시-19시  302398
# 15  19시-20시  178242
# 16  20시-21시  138452
# 17  21시-22시  157847
# 18  22시-23시  105997
# 19  23시-24시   12509
# 20  00시-01시       5
# 21  01시-02시       2
# 22  02시-03시       0
# 23  03시-04시       0

# %%
df_gangnam_in = df_gangnam_in.melt()

# %%
# 컬럼명 변경
df_gangnam_in.columns = ['시간대', '승차건수']
df_gangnam_in
# Out:
#         시간대    승차건수
# 0   04시-05시      64
# 1   05시-06시    4993
# 2   06시-07시   14177
# 3   07시-08시   31783
# 4   08시-09시   50239
# 5   09시-10시   40611
# 6   10시-11시   44108
# 7   11시-12시   59573
# 8   12시-13시   75942
# 9   13시-14시   88926
# 10  14시-15시   97964
# 11  15시-16시  120268
# 12  16시-17시  135621
# 13  17시-18시  214990
# 14  18시-19시  302398
# 15  19시-20시  178242
# 16  20시-21시  138452
# 17  21시-22시  157847
# 18  22시-23시  105997
# 19  23시-24시   12509
# 20  00시-01시       5
# 21  01시-02시       2
# 22  02시-03시       0
# 23  03시-04시       0

# %%
df_gangnam_in.sort_values('승차건수')
# Out:
#         시간대    승차건수
# 23  03시-04시       0
# 22  02시-03시       0
# 21  01시-02시       2
# 20  00시-01시       5
# 0   04시-05시      64
# 1   05시-06시    4993
# 19  23시-24시   12509
# 2   06시-07시   14177
# 3   07시-08시   31783
# 5   09시-10시   40611
# 6   10시-11시   44108
# 4   08시-09시   50239
# 7   11시-12시   59573
# 8   12시-13시   75942
# 9   13시-14시   88926
# 10  14시-15시   97964
# 18  22시-23시  105997
# 11  15시-16시  120268
# 12  16시-17시  135621
# 16  20시-21시  138452
# 17  21시-22시  157847
# 15  19시-20시  178242
# 13  17시-18시  214990
# 14  18시-19시  302398

# %%
# 시간대별 승차인원 시각화하기

df_gangnam_in
plt.figure(figsize=(10,6))
plt.barh(df_gangnam_in['시간대'], df_gangnam_in['승차건수'])
plt.show()

# %% [markdown]
# ## 강남역의 최근 하차 정보 분석

# %%
# 강남역의 최근 하차 데이터 불러오기 
df_out_202108.head(3)
# Out:
#       사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  202108  1호선  동대문       11     1815     5352     9885    19783    19192
# 1  202108  1호선  동묘앞        3      918     4614     8004    18779    15213
# 2  202108  1호선  서울역       11     5533    31479    73669   149249    94786
#
#    10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 0    17298  ...    16304    15398    10356     8870     7191     5983
# 1    17602  ...     9210     5827     3835     3839     3706     1759
# 2    50691  ...    61655    38909    25080    21490    13638     4968
#
#    00시-01시  01시-02시  02시-03시  03시-04시
# 0     1043        2        2        0
# 1      827        0        0        0
# 2      444        1        0        0
#
# [3 rows x 27 columns]

# %%
condition = df_out_202108['지하철역'] =='강남'
df_out_202108[condition]
# Out:
#        사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 10  202108  2호선   강남        4    10411    45059   129595   269877   274355
#
#     10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 10   129744  ...   125891    68747    34635    27783    21970     8377
#
#     00시-01시  01시-02시  02시-03시  03시-04시
# 10       15        1        0        0
#
# [1 rows x 27 columns]

# %%
df_out_202108[condition].iloc[:, 3:]
# Out:
#     04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 10        4    10411    45059   129595   269877   274355   129744    99120
#
#     12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 10    96644   115153  ...   125891    68747    34635    27783    21970
#
#     23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 10     8377       15        1        0        0
#
# [1 rows x 24 columns]

# %%
df_gangnam_out = df_out_202108[condition].iloc[:, 3:]

# %%
# melt
df_gangnam_out.melt()
# Out:
#    variable   value
# 0   04시-05시       4
# 1   05시-06시   10411
# 2   06시-07시   45059
# 3   07시-08시  129595
# 4   08시-09시  269877
# 5   09시-10시  274355
# 6   10시-11시  129744
# 7   11시-12시   99120
# 8   12시-13시   96644
# 9   13시-14시  115153
# 10  14시-15시   94620
# 11  15시-16시   86770
# 12  16시-17시   83690
# 13  17시-18시   96689
# 14  18시-19시  125891
# 15  19시-20시   68747
# 16  20시-21시   34635
# 17  21시-22시   27783
# 18  22시-23시   21970
# 19  23시-24시    8377
# 20  00시-01시      15
# 21  01시-02시       1
# 22  02시-03시       0
# 23  03시-04시       0

# %%
# melt
df_gangnam_out = df_gangnam_out.melt()

# %%
# 컬럼명 변경
df_gangnam_out.columns = ['시간대', '하차건수']
df_gangnam_out.head()
# Out:
#        시간대    하차건수
# 0  04시-05시       4
# 1  05시-06시   10411
# 2  06시-07시   45059
# 3  07시-08시  129595
# 4  08시-09시  269877

# %%
df_gangnam_out.sort_values('하차건수')
# Out:
#         시간대    하차건수
# 23  03시-04시       0
# 22  02시-03시       0
# 21  01시-02시       1
# 0   04시-05시       4
# 20  00시-01시      15
# 19  23시-24시    8377
# 1   05시-06시   10411
# 18  22시-23시   21970
# 17  21시-22시   27783
# 16  20시-21시   34635
# 2   06시-07시   45059
# 15  19시-20시   68747
# 12  16시-17시   83690
# 11  15시-16시   86770
# 10  14시-15시   94620
# 8   12시-13시   96644
# 13  17시-18시   96689
# 7   11시-12시   99120
# 9   13시-14시  115153
# 14  18시-19시  125891
# 3   07시-08시  129595
# 6   10시-11시  129744
# 4   08시-09시  269877
# 5   09시-10시  274355

# %%
# 시간대별 승차인원 시각화하기
df_gangnam_out
plt.figure(figsize=(10, 6))
plt.barh(df_gangnam_out['시간대'], df_gangnam_out['하차건수'])
plt.show()

# %%
# 멀티캠퍼스 선릉 캠퍼스 승하차 인원 파악하기

# %%
condition = df_in_202108['지하철역']=='선릉'
df_sl_in=df_in_202108[condition].iloc[:,3:]
df_sl_in
# Out:
#      04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 30        31     3035     8842    17142    25458    23985    28538    37028
# 508       16      963     1966     3712     5564     4850     6114     7539
#
#      12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 30     43792    49725  ...   245318   116743    69492    67774    50072
# 508     9286    10245  ...    67622    28847    16542    15989    12922
#
#      23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 30      6987        2        0        0        0
# 508     1238       33        0        0        0
#
# [2 rows x 24 columns]

# %%
df_sl_in.melt()
# Out:
#    variable   value
# 0   04시-05시      31
# 1   04시-05시      16
# 2   05시-06시    3035
# 3   05시-06시     963
# 4   06시-07시    8842
# 5   06시-07시    1966
# 6   07시-08시   17142
# 7   07시-08시    3712
# 8   08시-09시   25458
# 9   08시-09시    5564
# 10  09시-10시   23985
# 11  09시-10시    4850
# 12  10시-11시   28538
# 13  10시-11시    6114
# 14  11시-12시   37028
# 15  11시-12시    7539
# 16  12시-13시   43792
# 17  12시-13시    9286
# 18  13시-14시   49725
# 19  13시-14시   10245
# 20  14시-15시   60108
# 21  14시-15시   11265
# 22  15시-16시   74524
# 23  15시-16시   14460
# 24  16시-17시   98799
# 25  16시-17시   22391
# 26  17시-18시  153833
# 27  17시-18시   39086
# 28  18시-19시  245318
# 29  18시-19시   67622
# 30  19시-20시  116743
# 31  19시-20시   28847
# 32  20시-21시   69492
# 33  20시-21시   16542
# 34  21시-22시   67774
# 35  21시-22시   15989
# 36  22시-23시   50072
# 37  22시-23시   12922
# 38  23시-24시    6987
# 39  23시-24시    1238
# 40  00시-01시       2
# 41  00시-01시      33
# 42  01시-02시       0
# 43  01시-02시       0
# ...

# %%
df_sl_in=df_sl_in.melt()
df_sl_in.columns=['시간대','승차건수']
df_sl_in
# Out:
#         시간대    승차건수
# 0   04시-05시      31
# 1   04시-05시      16
# 2   05시-06시    3035
# 3   05시-06시     963
# 4   06시-07시    8842
# 5   06시-07시    1966
# 6   07시-08시   17142
# 7   07시-08시    3712
# 8   08시-09시   25458
# 9   08시-09시    5564
# 10  09시-10시   23985
# 11  09시-10시    4850
# 12  10시-11시   28538
# 13  10시-11시    6114
# 14  11시-12시   37028
# 15  11시-12시    7539
# 16  12시-13시   43792
# 17  12시-13시    9286
# 18  13시-14시   49725
# 19  13시-14시   10245
# 20  14시-15시   60108
# 21  14시-15시   11265
# 22  15시-16시   74524
# 23  15시-16시   14460
# 24  16시-17시   98799
# 25  16시-17시   22391
# 26  17시-18시  153833
# 27  17시-18시   39086
# 28  18시-19시  245318
# 29  18시-19시   67622
# 30  19시-20시  116743
# 31  19시-20시   28847
# 32  20시-21시   69492
# 33  20시-21시   16542
# 34  21시-22시   67774
# 35  21시-22시   15989
# 36  22시-23시   50072
# 37  22시-23시   12922
# 38  23시-24시    6987
# 39  23시-24시    1238
# 40  00시-01시       2
# 41  00시-01시      33
# 42  01시-02시       0
# 43  01시-02시       0
# ...

# %%
plt.figure(figsize=(10,6))
plt.barh(df_sl_in['시간대'],df_sl_in['승차건수'])
plt.show()

# %%
df1 = df_in_202108[df_in_202108["지하철역"] == "선릉"].iloc[:, 3:].melt()
plt.figure(figsize=(10, 6))
plt.barh(df1.variable, df1.value)
plt.show()

# %%
condition=df_in_202108['지하철역']=='선릉'
df_in_202108[condition].iloc[:,3:]
df_senrung_in=df_in_202108[condition].iloc[:,3:]
df_senrung_in=df_senrung_in.melt()
df_senrung_in.columns=['시간대','승차건수']
df_senrung_in
plt.figure(figsize=(10,6))
plt.barh(df_senrung_in['시간대'],df_senrung_in['승차건수'])
plt.show()

# %%
condition=df_out_202108['지하철역']=='선릉'
df_out_202108[condition].iloc[:,3:]
df_senrung_out=df_out_202108[condition].iloc[:,3:]
df_senrung_out=df_senrung_out.melt()
df_senrung_out.columns=['시간대','하차건수']
df_senrung_out.sort_values('하차건수')
df_senrung_out
plt.figure(figsize=(10,6))
plt.barh(df_senrung_out['시간대'], df_senrung_out['하차건수'])
plt.show()

# %% [markdown]
# # 지하철 시간대별, 역별 이용현황 분석

# %% [markdown]
# ## 시간대별 승차 현황

# %% [markdown]
# ### 승차정보 집계 데이터 만들기

# %%
# df_in_202108카피하여 사용하기
df_in_202108_copy = df_in_202108.copy()

# %%
df_in_202108_copy.head(2)
# Out:
#       사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 0  202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 1  202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
#
#    10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 0    13922  ...    20332    13464    10336     9669     6514     1633
# 1     9130  ...    19551     8704     5031     4235     2678      577
#
#    00시-01시  01시-02시  02시-03시  03시-04시
# 0        7        2        0        0
# 1        4        0        0        0
#
# [2 rows x 27 columns]

# %%
# 인덱스 변경('지하철역')
df_in_202108_copy.index = df_in_202108_copy['지하철역']
df_in_202108_copy
# Out:
#          사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 지하철역
# 동대문   202108  1호선  동대문      415    10380     7880    12037    16637    15671
# 동묘앞   202108  1호선  동묘앞       84     2861     3286     5128     8066     7541
# 서울역   202108  1호선  서울역      483     7963    10871    31643    49003    36383
# 시청    202108  1호선   시청        6     1597     2727     5971     6884     7541
# 신설동   202108  1호선  신설동      247     6828     7333    14821    20523    14881
# ...      ...  ...  ...      ...      ...      ...      ...      ...      ...
# 원덕    202108  중앙선   원덕       72      277      689      643      883      755
# 중랑    202108  중앙선   중랑      200     5961     8782    19739    18610    13213
# 지평    202108  중앙선   지평        0        1        2      347      218       18
# 팔당    202108  중앙선   팔당        1      212      788     1261     1267     1123
# 회기    202108  중앙선   회기      719    11133    18619    47471    59922    39563
#
# ...

# %%
# 컬럼 삭제('사용월','호선명','지하철역')
df_in_202108_copy.drop(columns=['사용월','호선명','지하철역'], inplace=True)

# %%
df_in_202108_copy
# Out:
#       04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 지하철역
# 동대문       415    10380     7880    12037    16637    15671    13922    15675
# 동묘앞        84     2861     3286     5128     8066     7541     9130    13369
# 서울역       483     7963    10871    31643    49003    36383    35273    41477
# 시청          6     1597     2727     5971     6884     7541     8328    12240
# 신설동       247     6828     7333    14821    20523    14881    13551    15578
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 원덕         72      277      689      643      883      755      661      584
# 중랑        200     5961     8782    19739    18610    13213     8053     7475
# 지평          0        1        2      347      218       18      325        2
# 팔당          1      212      788     1261     1267     1123     1208     1127
# 회기        719    11133    18619    47471    59922    39563    31469    31674
#
# ...

# %%
# 행,열 합계
df_in_202108_copy.apply('sum', axis=0) # 서로 다른 행끼리 합쳐줘(sum())
# Out:
# 04시-05시      125592
# 05시-06시     2679895
# 06시-07시     5392644
# 07시-08시    13007398
# 08시-09시    14639529
# 09시-10시     8962001
# 10시-11시     6688112
# 11시-12시     6762631
# 12시-13시     7277223
# 13시-14시     7301932
# 14시-15시     7314360
# 15시-16시     8054562
# 16시-17시     9285727
# 17시-18시    12846619
# 18시-19시    17191309
# 19시-20시     8671470
# 20시-21시     6611588
# 21시-22시     6032973
# 22시-23시     3852573
# 23시-24시      744365
# 00시-01시        6086
# 01시-02시          26
# 02시-03시           3
# 03시-04시           1
# dtype: int64

# %%
df_in_202108_copy.apply('sum', axis=1) # 서로 다른 열끼리 합쳐줘(sum())
# Out:
# 지하철역
# 동대문    274678
# 동묘앞    229111
# 서울역    938002
# 시청     448993
# 신설동    319277
#         ...
# 원덕       9789
# 중랑     139495
# 지평       1852
# 팔당      28424
# 회기     560588
# Length: 607, dtype: int64

# %% [markdown]
# ### 시간대별 승차건수

# %%
df_in_202108_copy.apply('sum', axis=0)[:-1].sort_values()
# Out:
# 03시-04시           1
# 02시-03시           3
# 01시-02시          26
# 00시-01시        6086
# 04시-05시      125592
# 23시-24시      744365
# 05시-06시     2679895
# 22시-23시     3852573
# 06시-07시     5392644
# 21시-22시     6032973
# 20시-21시     6611588
# 10시-11시     6688112
# 11시-12시     6762631
# 12시-13시     7277223
# 13시-14시     7301932
# 14시-15시     7314360
# 15시-16시     8054562
# 19시-20시     8671470
# 09시-10시     8962001
# 16시-17시     9285727
# 17시-18시    12846619
# 07시-08시    13007398
# 08시-09시    14639529
# 18시-19시    17191309
# dtype: int64

# %%
s_in = df_in_202108_copy.apply('sum', axis=0)[:-1].sort_values()

# %%
s_in.sort_index()
# Out:
# 00시-01시        6086
# 01시-02시          26
# 02시-03시           3
# 03시-04시           1
# 04시-05시      125592
# 05시-06시     2679895
# 06시-07시     5392644
# 07시-08시    13007398
# 08시-09시    14639529
# 09시-10시     8962001
# 10시-11시     6688112
# 11시-12시     6762631
# 12시-13시     7277223
# 13시-14시     7301932
# 14시-15시     7314360
# 15시-16시     8054562
# 16시-17시     9285727
# 17시-18시    12846619
# 18시-19시    17191309
# 19시-20시     8671470
# 20시-21시     6611588
# 21시-22시     6032973
# 22시-23시     3852573
# 23시-24시      744365
# dtype: int64

# %%
s_in = s_in.sort_index()
x = s_in.index
y = s_in.values
plt.bar(x, y)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 지하철역별 승차건수

# %%
df_in_202108_copy.apply('sum', axis=1) # 서로 다른 열끼리 합쳐줘(sum())
# Out:
# 지하철역
# 동대문     549356
# 동묘앞     458222
# 서울역    1876004
# 시청      897986
# 신설동     638554
#         ...
# 원덕       19578
# 중랑      278990
# 지평        3704
# 팔당       56848
# 회기     1121176
# Length: 607, dtype: int64

# %%
df_in_202108_copy.apply('sum', axis=1).sort_values(ascending=False).to_frame()
# Out:
#                 0
# 지하철역
# 강남        3749422
# 잠실(송파구청)  3078712
# 신림        3007208
# 구로디지털단지   2662608
# 홍대입구      2495864
# ...           ...
# 창동             12
# 계양             10
# 지축              8
# 검암              8
# 신내              6
#
# [607 rows x 1 columns]

# %% [markdown]
# ## 시간대별 하차 현황

# %% [markdown]
# ### 하차정보 집계 테이블 만들기

# %%
# df_out_202108카피하여 사용하기
df_out_202108_copy = df_out_202108.copy()

# %%
# 인덱스 변경('지하철역')
df_out_202108_copy['지하철역']
# Out:
# 0      동대문
# 1      동묘앞
# 2      서울역
# 3       시청
# 4      신설동
#       ...
# 602     원덕
# 603     중랑
# 604     지평
# 605     팔당
# 606     회기
# Name: 지하철역, Length: 607, dtype: object

# %%
df_out_202108_copy.index = df_out_202108_copy['지하철역']
df_out_202108_copy.head(3)
# Out:
#          사용월  호선명 지하철역  04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  \
# 지하철역
# 동대문   202108  1호선  동대문       11     1815     5352     9885    19783    19192
# 동묘앞   202108  1호선  동묘앞        3      918     4614     8004    18779    15213
# 서울역   202108  1호선  서울역       11     5533    31479    73669   149249    94786
#
#       10시-11시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  23시-24시  \
# 지하철역           ...
# 동대문     17298  ...    16304    15398    10356     8870     7191     5983
# 동묘앞     17602  ...     9210     5827     3835     3839     3706     1759
# 서울역     50691  ...    61655    38909    25080    21490    13638     4968
#
#       00시-01시  01시-02시  02시-03시  03시-04시
# 지하철역
# 동대문      1043        2        2        0
# 동묘앞       827        0        0        0
# 서울역       444        1        0        0
#
# [3 rows x 27 columns]

# %%
# 컬럼 삭제('사용월','호선명','지하철역')
df_out_202108_copy.drop(columns=['사용월','호선명','지하철역'], inplace=True)

# %%
df_out_202108_copy.head(3)
# Out:
#       04시-05시  05시-06시  06시-07시  07시-08시  08시-09시  09시-10시  10시-11시  11시-12시  \
# 지하철역
# 동대문        11     1815     5352     9885    19783    19192    17298    19346
# 동묘앞         3      918     4614     8004    18779    15213    17602    21823
# 서울역        11     5533    31479    73669   149249    94786    50691    42942
#
#       12시-13시  13시-14시  ...  18시-19시  19시-20시  20시-21시  21시-22시  22시-23시  \
# 지하철역                    ...
# 동대문     19492    18295  ...    16304    15398    10356     8870     7191
# 동묘앞     23065    24178  ...     9210     5827     3835     3839     3706
# 서울역     46909    45564  ...    61655    38909    25080    21490    13638
#
#       23시-24시  00시-01시  01시-02시  02시-03시  03시-04시
# 지하철역
# 동대문      5983     1043        2        2        0
# 동묘앞      1759      827        0        0        0
# 서울역      4968      444        1        0        0
#
# [3 rows x 24 columns]

# %%
# 행,열 합계
df_out_202108_copy.apply('sum', axis=0)
# Out:
# 04시-05시        1644
# 05시-06시      706189
# 06시-07시     3603606
# 07시-08시     8042590
# 08시-09시    17604264
# 09시-10시    11402630
# 10시-11시     7146549
# 11시-12시     6666215
# 12시-13시     7062738
# 13시-14시     7449305
# 14시-15시     7174578
# 15시-16시     7581218
# 16시-17시     8380236
# 17시-18시    10646691
# 18시-19시    16007443
# 19시-20시    12354319
# 20시-21시     7093483
# 21시-22시     6338999
# 22시-23시     5217987
# 23시-24시     2216218
# 00시-01시      214094
# 01시-02시          66
# 02시-03시          12
# 03시-04시           1
# dtype: int64

# %%
df_out_202108_copy.apply('sum', axis=1)
# Out:
# 지하철역
# 동대문    260656
# 동묘앞    235014
# 서울역    893346
# 시청     442944
# 신설동    316122
#         ...
# 원덕       9051
# 중랑     133345
# 지평       2019
# 팔당      28701
# 회기     547771
# Length: 607, dtype: int64

# %% [markdown]
# ### 시간대별 하차 건수

# %%
df_out_202108_copy.apply('sum', axis=0).sort_values(ascending=False).to_frame()
# Out:
#                 0
# 08시-09시  17604264
# 18시-19시  16007443
# 19시-20시  12354319
# 09시-10시  11402630
# 17시-18시  10646691
# 16시-17시   8380236
# 07시-08시   8042590
# 15시-16시   7581218
# 13시-14시   7449305
# 14시-15시   7174578
# 10시-11시   7146549
# 20시-21시   7093483
# 12시-13시   7062738
# 11시-12시   6666215
# 21시-22시   6338999
# 22시-23시   5217987
# 06시-07시   3603606
# 23시-24시   2216218
# 05시-06시    706189
# 00시-01시    214094
# 04시-05시      1644
# 01시-02시        66
# 02시-03시        12
# 03시-04시         1

# %%
s_out = df_out_202108_copy.apply('sum', axis=0).sort_values(ascending=False).to_frame()

# %%
s_out.sort_index()
# Out:
#                 0
# 00시-01시    214094
# 01시-02시        66
# 02시-03시        12
# 03시-04시         1
# 04시-05시      1644
# 05시-06시    706189
# 06시-07시   3603606
# 07시-08시   8042590
# 08시-09시  17604264
# 09시-10시  11402630
# 10시-11시   7146549
# 11시-12시   6666215
# 12시-13시   7062738
# 13시-14시   7449305
# 14시-15시   7174578
# 15시-16시   7581218
# 16시-17시   8380236
# 17시-18시  10646691
# 18시-19시  16007443
# 19시-20시  12354319
# 20시-21시   7093483
# 21시-22시   6338999
# 22시-23시   5217987
# 23시-24시   2216218

# %% [markdown]
# ### 지하철역별 하차건수

# %%
df_out_202108_copy.apply('sum', axis=1).sort_values(ascending=False).to_frame()
# Out:
#                 0
# 지하철역
# 강남        1819150
# 잠실(송파구청)  1514327
# 신림        1467939
# 구로디지털단지   1339493
# 홍대입구      1273453
# ...           ...
# 충무로             0
# 신내              0
# 연신내             0
# 검암              0
# 지축              0
#
# [607 rows x 1 columns]
