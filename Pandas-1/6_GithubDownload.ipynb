# %%
# google drive server를 연결하기 위한 라이브러리
from google.colab import drive

# %%
# 구글 드라이브를 colab server와 연결
import os
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# %% [markdown]
# ### 경로 이동

# %%
# !pwd # 현재 작업경로(present working directory)
# Out:
# /content

# %%
# !cd /content/drive/MyDrive  # cd : change directory(cf. win : folder)

# %%
#현재 경로가 어디로 설정되어 있는지
# !pwd
# Out:
# /content

# %% [markdown]
# ## 아래의 셀에 다운받고자 하는 사이트의 Github주소를 넣어준다.
#
# 리눅스 커널(엄청나게 큰 소프트웨어)의 버전을 관리하기 위해 만들어진 소프트웨어

# %%
if not os.path.exists('DataScience'):
    # !git clone https://github.com/PinkWink/DataScience.git

# %%
pwd
# Out:
# '/content'
